# %%
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt  
import seaborn as sns
# %matplotlib inline 
  
  
# load the dataset 
file_dir="SMOTE_folder/MSI_RMSI_files/U13_LIHF_itd_file.csv"
df = pd.read_csv(file_dir) 
  
# display 5 rows of dataset 
df.head()  
#df.boxplot(by ='label', column =['MSI'], grid = True,fontsize=16) 
#sns.set_style("whitegrid") 
sns.set_style("ticks")
b=sns.boxplot(x = 'label', y = 'MSI', data = df) 
#b.axes.set_title("Title",fontsize=50)
b.set_xlabel("Emotion state",fontsize=16)
b.set_ylabel("Mean session ITD",fontsize=16)
b.yaxis.set_tick_params(labelsize=16)
b.xaxis.set_tick_params(labelsize=16)
plt.tight_layout()
plt.savefig("test_MSI.jpg")
#b.tick_params(labelsize=5)
